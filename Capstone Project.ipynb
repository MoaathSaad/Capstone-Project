# %% [markdown]
# # Protein Products Advertising Campaign (Data Science Case Study)

# %% [markdown]
# ## 1 Introduction

# %% [markdown]
# ## 1.1 Description & Discussion of the Background

# %% [markdown]
# ### 1.1.1 General Discussion

# %% [markdown]
# Based on BBC <a href='http://www.bbc.co.uk/newsbeat/article/38555693/protein-supplement-advert-claims-wrong-and-immoral'>'Protein Supplement Advert Claims Wrong and Immoral'</a> article, The British Dietetic Association (BDA) believes marketing for some products is both "wrong and immoral". In which It means that thousands of people are using protein powders as a <strong>"Substitute not a supplement"</strong>. But the body which represents the sports nutrition industry says extra protein allows people to train harder.
# The ESSNA (European Specialist Sports Nutrition Alliance) also argues that synthetic products enable faster recovery.
# There's been a 20% year-on-year increase in sales of protein products over the last five years, according to Euromonitor figures obtained by Radio 1 Newsbeat.
# That makes them the fastest growing type of sport supplement in the UK.
# UK consumers spent £66m on sports nutrition food and drink products in 2015, up by 27% from 2013.
# A statistical review by "Protein Supplements Market Size & Growth, Industry Report 2018-2025" described the annual protein supplements revenues by Product:

# %% [markdown]
# <img src="https://www.grandviewresearch.com/static/img/research/us-protein-supplements-market.png" />

# %% [markdown]
# ### 1.1.2 Background

# %% [markdown]
# A company called Mass-Protein wants to start an advertising campaign for their new protein product in the city of Toronto and after several meetings the company made the plane of the process that need to be followed in order to get the highest value from there campaign, and it was as follow: -
# <ul >
#     <li>Create a map which illustrate the administrative division Toronto city.</li>
#     <li>Identifying the Boroughs including neighborhoods in Toronto.</li>
#     <li>Identifying the ratio of gyms in each Boroughs.</li>
#     <li>Start a Facebook, YouTube advertising campaign that targets people by their location.</li>
# <ul>

# %% [markdown]
# ## 1.2 Problem Statement

# %% [markdown]
# The company decided to invest a 100,000$ in this campaign and haired a Data Scientist to answer the following question: -
# <strong><font size="3em">What's the amount of budget will we invest in each area in the city of Toronto for the advertising campaign?</font></strong>

# %% [markdown]
# # 2. Implementation / Code

# %% [markdown]
# ### 2.1 Installing Required Library's
# Please if you haven't run the following code to install packages the remove the comments and run the code.

# %%
! pip install geocoder                              #For Installing GeoCoder Library
! conda install -c conda-forge geopy --yes          #For Installing Geopy Library
! conda install -c conda-forge folium=0.5.0 --yes   #For Installing Folium

# %% [markdown]
# ## 2.2. Importing Librarys

# %%
import numpy as np                        #For Vectorized Computation
import os as os                           #For File Proccessing
import folium                             #For Map Rendering
import requests                           #For HTTP Requests
import lxml.html as lh                    #For Html to ? Convertion
import pandas as pd                       #For Creating Dataframs
from lxml import etree                    #For Converting HTML Elements to Raw HTML
import geocoder                           #For Getting the latitude and longitude Coordinates
from geopy.geocoders import Nominatim     #For Converting an Address into latitude and longitude Values
import json                               #For handleing JSON files
from pandas.io.json import json_normalize #For Tranforming JSON File Into a Pandas Dataframe
from sklearn.cluster import KMeans        #For import K-means From Clustering Stage
import matplotlib.cm as cm                #For Matplotlib and associated plotting modules
import matplotlib.colors as colors        #For Matplotlib and associated plotting modules
from math import sin, cos, sqrt, atan2, radians #For Mathematical Operations
print('Importing Librarys Complete')
# Out:
# Importing Librarys Complete

# %% [markdown]
# ### 2.3. Loading Data
# ### 2.3.1. Loading Spatial Data

# %% [markdown]
# #### GIS Data (Second-level Administrative Divisions, Canada, 2015) - Loading Data

# %%
#Creating  File Structer
if(os.path.isdir('Data/SpatialData/') == False):
   os.mkdir("Data/SpatialData/")                                            #Create Data Directory

 
url = 'https://geo.nyu.edu/download/file/stanford-pg953dp1700-geojson.json' #Second-Level Administrative Spatial Data
GeoJSON_File = 'Data/SpatialData/Canada.json'

if(os.path.isfile(GeoJSON_File) == False):                                  #Check For File Existance
    print('Beginning file download with urllib2...')                        #Inform Us About Downloading Process
    urllib.request.urlretrieve(url, GeoJSON_File)                           #Saving File To Directory
    print('Download Completed!')                                            #Inform Completion
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-86c4307a0339> in <module>
#       1 #Creating  File Structer
#       2 if(os.path.isdir('Data/SpatialData/') == False):
# ----> 3    os.mkdir("Data/SpatialData/")                                            #Create Data Directory
#       4
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data/SpatialData/'

# %% [markdown]
# #### GIS Data (Third-level Administrative Divisions, Canada Toranto City, 2015)

# %% [markdown]
# ##### Toranto Raw Map

# %%
Toranto_map = folium.Map(location=[43.652051, -79.382646], zoom_start=11)
Toranto_map

# %%
Toranto_map = folium.Map(location=[43.652051, -79.382646], zoom_start=11)
folium.Choropleth(geo_data='Toranto.geojson',
                  key_on='feature.properties.DISTRICT'
                   ).add_to(Toranto_map)
Toranto_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 2.3.2. Loading Borough, Latitude and Longitude Data

# %% [markdown]
# On the following wikipedia page:
# https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
# There is a list of postal codes of Canada which will help us in preperation the data.

# %%
Table_Class = "wikitable sortable"

wikipedia_url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'  #Page Url
page = requests.get(wikipedia_url)                                               #Get the Page
doc = lh.fromstring(page.content)                                                #getting the contents of the website

#Now we will get the wikipedia table that has a class attribute thet contints "wikitable sortable"
results  = doc.xpath("//table[@class='%s']" % Table_Class )

table = results[0]          #Getting The Table Which Should be the First in List (as HTML Element)
raw = etree.tostring(table) #Getting Raw HTML From HTML Element
df = pd.read_html(raw)[0]   #Use Pandas 'read_html' Function to Convert From HTML to Dataframe

df.head()                   #Printing Result Dataframe
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %% [markdown]
# ### 2.3.3. Cleaning Data
# First we will delete every row that has 'Borough' value is not assign, then we will copy the value of 'Borough' column to 'Neighbourhood' that has no value and after that we will reset the dataframe index. Next is kind of tricky; we will group data based on 'Postcode' and aggregate the child value into one cell but separate them by a comma

# %%
df.drop(df.loc[df['Borough'] == "Not assigned"].index, inplace=True)         #Removing Rows That Has "Not assigned" Value
df.loc[df['Neighbourhood'] == "Not assigned" , 'Neighbourhood'] = df['Borough'];
df = df.reset_index(drop=True)                                               #Reseting Index
tmp = df.groupby(['Postcode'])['Neighbourhood'].agg(', '.join).reset_index() #Grouping Data
tmp['Borough'] = df.groupby(['Postcode'])['Borough'].first().reset_index()['Borough']
df = tmp                                 
df.shape
# Out:
# (103, 3)

# %% [markdown]
# ### 2.3.4. Preparing Latitude and Longitude

# %%
lldf = pd.read_csv('Geospatial_Coordinates.csv')
df['Latitude'] = lldf.loc[lldf['Postal Code'] == df['Postcode'] , 'Latitude']
df['Longitude'] = lldf.loc[lldf['Postal Code'] == df['Postcode'] , 'Longitude']

df.head()
# Out:
#   Postcode                           Neighbourhood      Borough   Latitude  \
# 0      M1B                          Rouge, Malvern  Scarborough  43.806686
# 1      M1C  Highland Creek, Rouge Hill, Port Union  Scarborough  43.784535
# 2      M1E       Guildwood, Morningside, West Hill  Scarborough  43.763573
# 3      M1G                                  Woburn  Scarborough  43.770992
# 4      M1H                               Cedarbrae  Scarborough  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %%
# create map of Toronto using latitude and longitude values
Toranto_map = folium.Map(location=[43.652051, -79.382646], zoom_start=11)

# add markers to map
for _latitude, _longitude, _borough, _neighborhood in zip(df['Latitude'], df['Longitude'], df['Borough'], df['Neighbourhood']):
    label = '{}, {}'.format(_neighborhood, _borough)
    label = folium.Popup(label, parse_html=True)
    
                                #In Order To Create a Circle Marker Like the One on Google Then We'll Use the Folium Object 'CircleMarker'
    folium.CircleMarker(        #And Add The Following Parameters: -
        [_latitude, _longitude],                #1- Latitude And Longitude
        radius=5,                               #2- The Radius of the Circle
        popup=label,                            #3- The Lable That Will Pop Up
        color='blue',                           #4- The Color of the Circle
        fill=True,                              #5- Set Fill to True In Order to Fill the Circle
        fill_color='#3186cc',                   #6- This Parameter Represents the Filling Color
        fill_opacity=0.7,                       #7- The Level of Filling Opacity (Value Between 0 and 1)
        parse_html=False,                       #8-
        ).add_to(Toranto_map)                   #Lastly We Assign the Marker to Our Map
    
Toranto_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 2.4. Getting Data About Gyms In Every Nighborhood

# %% [markdown]
# Getting All Toranto Gyms

# %%
CLIENT_ID = 'JYOC5WGRXKGGJN1LVBVVHA5RHQHCGSENQK2BCKKVNUQMHA2N'         # your Foursquare ID
CLIENT_SECRET = '0PI04RLZDG1SLY2DB2UV0ON45VHOH2QPDSDC00HPHESMRDYQ'     # your Foursquare Secret

# %%
# create URL ////43.562775, -79.589391 ///43.875118, -79.127508
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v=20180605&intent=match&ll=43.652051, -79.382646&city={}&query=gym&Limit=500&radius=10000'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    'Toronto')
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=JYOC5WGRXKGGJN1LVBVVHA5RHQHCGSENQK2BCKKVNUQMHA2N&client_secret=0PI04RLZDG1SLY2DB2UV0ON45VHOH2QPDSDC00HPHESMRDYQ&v=20180605&intent=match&ll=43.652051, -79.382646&city=Toronto&query=gym&Limit=500&radius=10000'

# %%
#Scarborough, North York, East York, East Toronto,Central Toronto, Downtown Toronto, York, West Toronto,Queen's Park, Mississauga, Etobicoke
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c7818cadb04f505a3602496'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Toronto',
#   'headerFullLocation': 'Toronto',
#   'headerLocationGranularity': 'city',
#   'query': 'gym',
#   'totalResults': 279,
#   'suggestedBounds': {'ne': {'lat': 43.74205109000009,
#     'lng': -79.25849056966459},
#    'sw': {'lat': 43.56205090999991, 'lng': -79.5068014303354}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dc842f2e4cd5bc076711d90',
#        'name': 'GoodLife Fitness',
#        'location': {'address': '137 Yonge St',
#         'crossStreet': 'at Richmond St',
#         'lat': 43.65113563166627,
#         'lng': -79.37879687835455,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65113563166627,
#           'lng': -79.37879687835455}],
#         'distance': 326,
#         'postalCode': 'M5C 1W6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['137 Yonge St (at Richmond St)',
#          'Toronto ON M5C 1W6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dc842f2e4cd5bc076711d90-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '501ae947e4b0d11883b910a7',
#        'name': 'Equinox Bay Street',
#        'location': {'address': '199 Bay St',
#         'crossStreet': 'at Commerce Court West, PATH Level',
#         'lat': 43.64809974034856,
#         'lng': -79.37998869411526,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64809974034856,
#           'lng': -79.37998869411526}],
#         'distance': 489,
#         'postalCode': 'M5L 1L5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['199 Bay St (at Commerce Court West, PATH Level)',
#          'Toronto ON M5L 1L5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-501ae947e4b0d11883b910a7-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52cc8576498eda8bc7cd774e',
#        'name': 'GoodLife Fitness',
#        'location': {'address': '555 Richmond St W',
#         'crossStreet': 'Bathurst and Richmond',
#         'lat': 43.64655588952475,
#         'lng': -79.40265968543741,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64655588952475,
#           'lng': -79.40265968543741}],
#         'distance': 1724,
#         'postalCode': 'M5V 3B1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['555 Richmond St W (Bathurst and Richmond)',
#          'Toronto ON M5V 3B1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52cc8576498eda8bc7cd774e-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ea43642be7ba4918efc5afa',
#        'name': 'Adelaide Club Toronto',
#        'location': {'address': '1 First Canadian Place',
#         'lat': 43.64927944291712,
#         'lng': -79.38192123284551,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64927944291712,
#           'lng': -79.38192123284551}],
#         'distance': 314,
#         'postalCode': 'M5X 1C8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1 First Canadian Place',
#          'Toronto ON M5X 1C8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'shortName': 'Gym / Fitness',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ea43642be7ba4918efc5afa-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ae49933f964a520289c21e3',
#        'name': 'Totum Life Science King',
#        'location': {'address': '445 King St. W',
#         'crossStreet': 'at Spadina Ave.',
#         'lat': 43.64515094558113,
#         'lng': -79.39591777216019,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64515094558113,
#           'lng': -79.39591777216019}],
#         'distance': 1316,
#         'postalCode': 'M5V 1K4',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['445 King St. W (at Spadina Ave.)',
#          'Toronto ON M5V 1K4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ae49933f964a520289c21e3-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54c3c353498eeda167779797',
#        'name': 'barre3 Toronto - King St. West',
#        'location': {'address': '325 King Street West',
#         'lat': 43.646317516225395,
#         'lng': -79.39094024700876,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.646317516225395,
#           'lng': -79.39094024700876}],
#         'distance': 923,
#         'postalCode': 'M5V 1M3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['325 King Street West',
#          'Toronto ON M5V 1M3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'shortName': 'Gym / Fitness',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54c3c353498eeda167779797-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5171e5bae412554f0a1dbe18',
#        'name': 'Fuel Training Club',
#        'location': {'address': '45 camden st unit 100',
#         'crossStreet': 'spadina',
#         'lat': 43.646823,
#         'lng': -79.397917,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.646823,
#           'lng': -79.397917}],
#         'distance': 1360,
#         'postalCode': 'm5v1v2',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['45 camden st unit 100 (spadina)',
#          'Toronto ON m5v1v2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '55818897'}},
#       'referralId': 'e-0-5171e5bae412554f0a1dbe18-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c97dc5200ec3704f781e5bf',
#        'name': 'Superclub',
#        'location': {'address': '35 Mariner Terrace',
#         'crossStreet': 'Spadina Ave and Bremner Blvd',
#         'lat': 43.63976132108351,
#         'lng': -79.39114334001921,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.63976132108351,
#           'lng': -79.39114334001921}],
#         'distance': 1529,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['35 Mariner Terrace (Spadina Ave and Bremner Blvd)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c97dc5200ec3704f781e5bf-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56b8d8c7498e61baf4099322',
#        'name': 'Equinox Yorkville',
#        'location': {'address': '55 Avenue Road',
#         'lat': 43.67122,
#         'lng': -79.394963,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67122,
#           'lng': -79.394963}],
#         'distance': 2353,
#         'postalCode': 'M5R 1B9',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['55 Avenue Road',
#          'Toronto ON M5R 1B9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56b8d8c7498e61baf4099322-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ae4c20bf964a520d79d21e3',
#        'name': 'Moksha Yoga Downtown',
#        'location': {'address': '577 Wellington St W',
#         'crossStreet': 'at Bathurst St',
#         'lat': 43.64235253746307,
#         'lng': -79.40318498512346,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64235253746307,
#           'lng': -79.40318498512346}],
#         'distance': 1975,
#         'postalCode': 'M5V 1G3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['577 Wellington St W (at Bathurst St)',
#          'Toronto ON M5V 1G3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ae4c20bf964a520d79d21e3-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '574c229e498ebb5c6b257902',
#        'name': 'Toronto Cooper Koo Family Cherry St YMCA Centre',
#        'location': {'address': '461 Cherry Street',
#         'lat': 43.65319052672638,
#         'lng': -79.35794700053884,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65319052672638,
#           'lng': -79.35794700053884}],
#         'distance': 1993,
#         'postalCode': 'M5A 1H1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['461 Cherry Street',
#          'Toronto ON M5A 1H1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'shortName': 'Gym / Fitness',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-574c229e498ebb5c6b257902-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad8d773f964a5203e1521e3',
#        'name': 'YMCA',
#        'location': {'address': '20 Grosvenor St',
#         'crossStreet': 'btwn St. Vincent Ln & St. Lukes Ln',
#         'lat': 43.66275344493089,
#         'lng': -79.3848492869005,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.66275344493089,
#           'lng': -79.3848492869005}],
#         'distance': 1204,
#         'postalCode': 'M4Y 2V5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['20 Grosvenor St (btwn St. Vincent Ln & St. Lukes Ln)',
#          'Toronto ON M4Y 2V5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad8d773f964a5203e1521e3-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcfcf3f964a520356321e3',
#        'name': 'GoodLife Fitness Toronto Richmond John',
#        'location': {'address': '267 Richmond St W',
#         'lat': 43.64871695511453,
#         'lng': -79.39206697894498,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64871695511453,
#           'lng': -79.39206697894498}],
#         'distance': 844,
#         'postalCode': 'M5V 3M6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['267 Richmond St W',
#          'Toronto ON M5V 3M6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcfcf3f964a520356321e3-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b720406f964a520346a2de3',
#        'name': 'Cykl',
#        'location': {'address': '68 Bathurst St.',
#         'crossStreet': 'At Wellington St. W',
#         'lat': 43.64277841041074,
#         'lng': -79.40236103414381,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64277841041074,
#           'lng': -79.40236103414381}],
#         'distance': 1894,
#         'postalCode': 'M5V 2P5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['68 Bathurst St. (At Wellington St. W)',
#          'Toronto ON M5V 2P5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'shortName': 'Gym / Fitness',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b720406f964a520346a2de3-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bcfa0c641b9ef3ba1e3f8e5',
#        'name': 'West End YMCA',
#        'location': {'address': '931 College St.',
#         'lat': 43.6536258574027,
#         'lng': -79.42609155145632,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6536258574027,
#           'lng': -79.42609155145632}],
#         'distance': 3503,
#         'postalCode': 'M6H 1A1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['931 College St.',
#          'Toronto ON M6H 1A1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bcfa0c641b9ef3ba1e3f8e5-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50885719498ea7b5aab3a74c',
#        'name': 'GoodLife Fitness',
#        'location': {'address': '483 Bay St',
#         'lat': 43.65374320109676,
#         'lng': -79.3827049601948,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65374320109676,
#           'lng': -79.3827049601948}],
#         'distance': 188,
#         'postalCode': 'M5G 2C9',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['483 Bay St', 'Toronto ON M5G 2C9', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50885719498ea7b5aab3a74c-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ea73a4df5b917316fb2fe5e',
#        'name': 'Cardio-Go',
#        'location': {'address': '266 King Street West',
#         'crossStreet': 'Duncan',
#         'lat': 43.64701650155176,
#         'lng': -79.38814275495332,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64701650155176,
#           'lng': -79.38814275495332}],
#         'distance': 714,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['266 King Street West (Duncan)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ea73a4df5b917316fb2fe5e-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4eee43b39adf257d67bf33f5',
#        'name': 'Academy Of Lions CrossFit Toronto',
#        'location': {'address': '64 Ossington Ave',
#         'lat': 43.645717362325456,
#         'lng': -79.41943732169375,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.645717362325456,
#           'lng': -79.41943732169375}],
#         'distance': 3046,
#         'postalCode': 'M6J 1X6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['64 Ossington Ave',
#          'Toronto ON M6J 1X6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'shortName': 'Gym / Fitness',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '37325322'}},
#       'referralId': 'e-0-4eee43b39adf257d67bf33f5-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f54ef6ce4b0929810978bb6',
#        'name': 'Reebok Crossfit Liberty Village',
#        'location': {'address': 'Liberty Village',
#         'lat': 43.637035591932005,
#         'lng': -79.42480199455974,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.637035591932005,
#           'lng': -79.42480199455974}],
#         'distance': 3784,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['Liberty Village', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f54ef6ce4b0929810978bb6-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '505b8b544c7fd4d07eae01f3',
#        'name': 'GoodLife Fitness',
#        'location': {'address': '36 Toronto St,210',
#         'crossStreet': 'at Victoria St.',
#         'lat': 43.650805604431795,
#         'lng': -79.37669340479917,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.650805604431795,
#           'lng': -79.37669340479917}],
#         'distance': 499,
#         'postalCode': 'M5C 2C5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['36 Toronto St,210 (at Victoria St.)',
#          'Toronto ON M5C 2C5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-505b8b544c7fd4d07eae01f3-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53f5e2fd498ee389ab52b446',
#        'name': 'Hone Fitness',
#        'location': {'address': '7 Isabella Street',
#         'crossStreet': 'Yonge Street',
#         'lat': 43.66748371662793,
#         'lng': -79.38551016951237,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.66748371662793,
#           'lng': -79.38551016951237}],
#         'distance': 1733,
#         'postalCode': 'M4Y 1M7',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['7 Isabella Street (Yonge Street)',
#          'Toronto ON M4Y 1M7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53f5e2fd498ee389ab52b446-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ae04bcaf964a520857e21e3',
#        'name': 'GoodLife Fitness Toronto Bloor Park',
#        'location': {'address': '8 Park Rd',
#         'crossStreet': 'at Bloor St. E.',
#         'lat': 43.67139808558312,
#         'lng': -79.3844083017028,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67139808558312,
#           'lng': -79.3844083017028}],
#         'distance': 2158,
#         'postalCode': 'M4W 3G8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['8 Park Rd (at Bloor St. E.)',
#          'Toronto ON M4W 3G8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ae04bcaf964a520857e21e3-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ee62e218b81bab285100b5a',
#        'name': 'Crossfit 416',
#        'location': {'address': '370 Queens Quay W, Unit 114',
#         'crossStreet': 'Spadina Ave',
#         'lat': 43.63819496273582,
#         'lng': -79.39069572966437,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.63819496273582,
#           'lng': -79.39069572966437}],
#         'distance': 1673,
#         'postalCode': 'M5V 3A6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['370 Queens Quay W, Unit 114 (Spadina Ave)',
#          'Toronto ON M5V 3A6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ee62e218b81bab285100b5a-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ae8c418f964a52019b221e3',
#        'name': 'Athletic Centre',
#        'location': {'address': '55 Harbord St',
#         'crossStreet': 'University of Toronto',
#         'lat': 43.66248699305214,
#         'lng': -79.40065676565847,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.66248699305214,
#           'lng': -79.40065676565847}],
#         'distance': 1858,
#         'postalCode': 'M5S 2W6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['55 Harbord St (University of Toronto)',
#          'Toronto ON M5S 2W6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1b2941735',
#          'name': 'College Gym',
#          'pluralName': 'College Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ae8c418f964a52019b221e3-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adf9fb1f964a520407c21e3',
#        'name': 'GoodLife Fitness Toronto King Liberty',
#        'location': {'address': '85 Hanna Ave',
#         'crossStreet': 'at Snooker St.',
#         'lat': 43.640174580568,
#         'lng': -79.41979117332932,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.640174580568,
#           'lng': -79.41979117332932}],
#         'distance': 3271,
#         'postalCode': 'M6K 3S3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['85 Hanna Ave (at Snooker St.)',
#          'Toronto ON M6K 3S3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adf9fb1f964a520407c21e3-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b2eca20f964a520b8e624e3',
#        'name': 'YogaSpace',
#        'location': {'address': '148 Ossington Avenue',
#         'crossStreet': 'Dundas',
#         'lat': 43.64760744635252,
#         'lng': -79.42013338783642,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64760744635252,
#           'lng': -79.42013338783642}],
#         'distance': 3059,
#         'postalCode': 'M6J 2Z5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['148 Ossington Avenue (Dundas)',
#          'Toronto ON M6J 2Z5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b2eca20f964a520b8e624e3-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba5156cf964a520b6da38e3',
#        'name': 'Toronto Lawn Tennis Club',
#        'location': {'address': '44 Price St.',
#         'crossStreet': 'at Yonge St.',
#         'lat': 43.68066694338894,
#         'lng': -79.38855887912045,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.68066694338894,
#           'lng': -79.38855887912045}],
#         'distance': 3220,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['44 Price St. (at Yonge St.)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4f4528bc4b90abdf24c9de85',
#          'name': 'Athletics & Sports',
#          'pluralName': 'Athletics & Sports',
#          'shortName': 'Athletics & Sports',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ba5156cf964a520b6da38e3-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fa30e16e4b0e966814a026e',
#        'name': 'Barreworks',
#        'location': {'address': '625 Queen St. W., 3rd Fl.',
#         'crossStreet': 'nr Bathurst St.',
#         'lat': 43.64732263896442,
#         'lng': -79.40296435435697,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64732263896442,
#           'lng': -79.40296435435697}],
#         'distance': 1719,
#         'postalCode': 'M5V 3Z1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['625 Queen St. W., 3rd Fl. (nr Bathurst St.)',
#          'Toronto ON M5V 3Z1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'shortName': 'Gym / Fitness',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '36182747'}},
#       'referralId': 'e-0-4fa30e16e4b0e966814a026e-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c8166f4d34ca143fc272280',
#        'name': 'Toronto Athletic Club',
#        'location': {'address': '79 Wellington Street West',
#         'lat': 43.647359553534905,
#         'lng': -79.3811766566002,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.647359553534905,
#           'lng': -79.3811766566002}],
#         'distance': 535,
#         'postalCode': 'M5K 1J5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['79 Wellington Street West',
#          'Toronto ON M5K 1J5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c8166f4d34ca143fc272280-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e21f9fbcc3fee7eee221f0f',
#        'name': 'Rock Oasis',
#        'location': {'address': '388 Carlaw Ave.',
#         'crossStreet': 'at Dundas (Suite 204)',
#         'lat': 43.6658798136579,
#         'lng': -79.34279442481119,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6658798136579,
#           'lng': -79.34279442481119}],
#         'distance': 3559,
#         'postalCode': 'M4M 2T4',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['388 Carlaw Ave. (at Dundas (Suite 204))',
#          'Toronto ON M4M 2T4',
#          'Canada']},
#        'categories': [{'id': '503289d391d4c4b30a586d6a',
#          'name': 'Climbing Gym',
#          'pluralName': 'Climbing Gyms',
#          'shortName': 'Climbing Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e21f9fbcc3fee7eee221f0f-29'}]}]}}

# %%
venues = results['response']['groups'][0]['items']
nearby_venues = json_normalize(venues) # flatten JSON
nearby_venues.head()
nearby_venues.shape
# Out:
# (30, 21)

# %% [markdown]
# <strong>#Returned (30, 23)</strong>

# %%
filtered_columns = ['venue.name' , 'venue.location.neighborhood' , 'venue.categories', 
                    'venue.location.address', 'venue.location.crossStreet',
                    'venue.location.formattedAddress'
                    ,'venue.location.postalCode', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
# /home/jupyterlab/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#                       name  neighborhood  \
# 0         GoodLife Fitness           NaN
# 1       Equinox Bay Street           NaN
# 2         GoodLife Fitness           NaN
# 3    Adelaide Club Toronto           NaN
# 4  Totum Life Science King           NaN
#
#                                           categories                 address  \
# 0  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...            137 Yonge St
# 1  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...              199 Bay St
# 2  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...       555 Richmond St W
# 3  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...  1 First Canadian Place
# 4  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...          445 King St. W
#
#                           crossStreet  \
# 0                      at Richmond St
# 1  at Commerce Court West, PATH Level
# 2               Bathurst and Richmond
# 3                                 NaN
# 4                     at Spadina Ave.
#
#                                     formattedAddress postalCode        lat  \
# 0  [137 Yonge St (at Richmond St), Toronto ON M5C...    M5C 1W6  43.651136
# 1  [199 Bay St (at Commerce Court West, PATH Leve...    M5L 1L5  43.648100
# 2  [555 Richmond St W (Bathurst and Richmond), To...    M5V 3B1  43.646556
# 3  [1 First Canadian Place, Toronto ON M5X 1C8, C...    M5X 1C8  43.649279
# 4  [445 King St. W (at Spadina Ave.), Toronto ON ...    M5V 1K4  43.645151
#
#          lng
# 0 -79.378797
# 1 -79.379989
# 2 -79.402660
# 3 -79.381921
# 4 -79.395918

# %% [markdown]
# ### 2.4.1. Cleaning Venues By Category

# %% [markdown]
# In here we'll need to ensure that every venue in the dataframe belongs to one of the following category's:

# %% [raw]
# ----------------------------------------------------
# | Category             |          Code             |
# ----------------------------------------------------
# | College Gym          |  4bf58dd8d48988d1b2941735 |
# | Gym / Fitness Center |  4bf58dd8d48988d175941735 |
# | Boxing Gym           |  52f2ab2ebcbc57f1066b8b47 |
# | Gymnastics Gym       |  52f2ab2ebcbc57f1066b8b48 |
# | Gym                  |  4bf58dd8d48988d176941735 |
# | Outdoor Gym          |  58daa1558bbb0b01f18ec203 |
# ----------------------------------------------------

# %% [markdown]
# So the first thing that we'll need to do is crating two function for extracting category

# %%
#Used for getting category name
def get_category_name(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
#Used for getting category Id
def get_category_id(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['id']

# %%
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_id, axis=1)
nearby_venues['venue.categorie.name'] = nearby_venues.apply(get_category_name, axis=1)
nearby_venues.head()
# Out:
#                       name  neighborhood  \
# 0         GoodLife Fitness           NaN
# 1       Equinox Bay Street           NaN
# 2         GoodLife Fitness           NaN
# 3    Adelaide Club Toronto           NaN
# 4  Totum Life Science King           NaN
#
#                                           categories                 address  \
# 0  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...            137 Yonge St
# 1  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...              199 Bay St
# 2  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...       555 Richmond St W
# 3  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...  1 First Canadian Place
# 4  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...          445 King St. W
#
#                           crossStreet  \
# 0                      at Richmond St
# 1  at Commerce Court West, PATH Level
# 2               Bathurst and Richmond
# 3                                 NaN
# 4                     at Spadina Ave.
#
#                                     formattedAddress postalCode        lat  \
# 0  [137 Yonge St (at Richmond St), Toronto ON M5C...    M5C 1W6  43.651136
# 1  [199 Bay St (at Commerce Court West, PATH Leve...    M5L 1L5  43.648100
# 2  [555 Richmond St W (Bathurst and Richmond), To...    M5V 3B1  43.646556
# 3  [1 First Canadian Place, Toronto ON M5X 1C8, C...    M5X 1C8  43.649279
# 4  [445 King St. W (at Spadina Ave.), Toronto ON ...    M5V 1K4  43.645151
#
#          lng          venue.categories  venue.categorie.name
# 0 -79.378797  4bf58dd8d48988d176941735                   Gym
# 1 -79.379989  4bf58dd8d48988d176941735                   Gym
# 2 -79.402660  4bf58dd8d48988d176941735                   Gym
# 3 -79.381921  4bf58dd8d48988d175941735  Gym / Fitness Center
# 4 -79.395918  4bf58dd8d48988d176941735                   Gym

# %% [markdown]
# ### 2.4.2. Formatting Venues PostalCode

# %%
Gym_per_Post  = nearby_venues
Gym_per_Post.postalCode = Gym_per_Post.postalCode.str.slice(stop=3).str.upper()
Gym_per_Post.head(100)
# Out:
#                                                name  neighborhood  \
# 0                                  GoodLife Fitness           NaN
# 1                                Equinox Bay Street           NaN
# 2                                  GoodLife Fitness           NaN
# 3                             Adelaide Club Toronto           NaN
# 4                           Totum Life Science King           NaN
# 5                    barre3 Toronto - King St. West           NaN
# 6                                Fuel Training Club           NaN
# 7                                         Superclub           NaN
# 8                                 Equinox Yorkville           NaN
# 9                              Moksha Yoga Downtown           NaN
# 10  Toronto Cooper Koo Family Cherry St YMCA Centre           NaN
# 11                                             YMCA           NaN
# 12           GoodLife Fitness Toronto Richmond John           NaN
# 13                                             Cykl           NaN
# 14                                    West End YMCA           NaN
# 15                                 GoodLife Fitness           NaN
# 16                                        Cardio-Go           NaN
# 17                Academy Of Lions CrossFit Toronto           NaN
# 18                  Reebok Crossfit Liberty Village           NaN
# 19                                 GoodLife Fitness           NaN
# 20                                     Hone Fitness           NaN
# 21              GoodLife Fitness Toronto Bloor Park           NaN
# 22                                     Crossfit 416           NaN
# 23                                  Athletic Centre           NaN
# 24            GoodLife Fitness Toronto King Liberty           NaN
# 25                                        YogaSpace           NaN
# 26                         Toronto Lawn Tennis Club           NaN
# 27                                       Barreworks           NaN
# 28                            Toronto Athletic Club           NaN
# 29                                       Rock Oasis           NaN
#
#                                            categories  \
# 0   [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 1   [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 2   [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 3   [{'id': '4bf58dd8d48988d175941735', 'name': 'G...
# 4   [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 5   [{'id': '4bf58dd8d48988d175941735', 'name': 'G...
# 6   [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 7   [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 8   [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 9   [{'id': '4bf58dd8d48988d102941735', 'name': 'Y...
# 10  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...
# 11  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 12  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 13  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...
# 14  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 15  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 16  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 17  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...
# 18  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 19  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 20  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 21  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 22  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 23  [{'id': '4bf58dd8d48988d1b2941735', 'name': 'C...
# 24  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 25  [{'id': '4bf58dd8d48988d102941735', 'name': 'Y...
# 26  [{'id': '4f4528bc4b90abdf24c9de85', 'name': 'A...
# 27  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...
# 28  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 29  [{'id': '503289d391d4c4b30a586d6a', 'name': 'C...
#
#                         address                         crossStreet  \
# 0                  137 Yonge St                      at Richmond St
# 1                    199 Bay St  at Commerce Court West, PATH Level
# 2             555 Richmond St W               Bathurst and Richmond
# 3        1 First Canadian Place                                 NaN
# 4                445 King St. W                     at Spadina Ave.
# 5          325 King Street West                                 NaN
# 6         45 camden st unit 100                             spadina
# 7            35 Mariner Terrace        Spadina Ave and Bremner Blvd
# 8                55 Avenue Road                                 NaN
# 9           577 Wellington St W                      at Bathurst St
# 10            461 Cherry Street                                 NaN
# 11              20 Grosvenor St  btwn St. Vincent Ln & St. Lukes Ln
# 12            267 Richmond St W                                 NaN
# 13              68 Bathurst St.                 At Wellington St. W
# 14              931 College St.                                 NaN
# 15                   483 Bay St                                 NaN
# 16         266 King Street West                              Duncan
# 17             64 Ossington Ave                                 NaN
# 18              Liberty Village                                 NaN
# 19            36 Toronto St,210                     at Victoria St.
# 20            7 Isabella Street                        Yonge Street
# 21                    8 Park Rd                     at Bloor St. E.
# 22  370 Queens Quay W, Unit 114                         Spadina Ave
# 23                55 Harbord St               University of Toronto
# 24                 85 Hanna Ave                      at Snooker St.
# 25         148 Ossington Avenue                              Dundas
# 26                 44 Price St.                        at Yonge St.
# 27    625 Queen St. W., 3rd Fl.                     nr Bathurst St.
# 28    79 Wellington Street West                                 NaN
# 29              388 Carlaw Ave.               at Dundas (Suite 204)
#
#                                      formattedAddress postalCode        lat  \
# 0   [137 Yonge St (at Richmond St), Toronto ON M5C...        M5C  43.651136
# 1   [199 Bay St (at Commerce Court West, PATH Leve...        M5L  43.648100
# 2   [555 Richmond St W (Bathurst and Richmond), To...        M5V  43.646556
# 3   [1 First Canadian Place, Toronto ON M5X 1C8, C...        M5X  43.649279
# 4   [445 King St. W (at Spadina Ave.), Toronto ON ...        M5V  43.645151
# 5   [325 King Street West, Toronto ON M5V 1M3, Can...        M5V  43.646318
# 6   [45 camden st unit 100 (spadina), Toronto ON m...        M5V  43.646823
# 7   [35 Mariner Terrace (Spadina Ave and Bremner B...        NaN  43.639761
# 8        [55 Avenue Road, Toronto ON M5R 1B9, Canada]        M5R  43.671220
# 9   [577 Wellington St W (at Bathurst St), Toronto...        M5V  43.642353
# 10    [461 Cherry Street, Toronto ON M5A 1H1, Canada]        M5A  43.653191
# 11  [20 Grosvenor St (btwn St. Vincent Ln & St. Lu...        M4Y  43.662753
# 12    [267 Richmond St W, Toronto ON M5V 3M6, Canada]        M5V  43.648717
# 13  [68 Bathurst St. (At Wellington St. W), Toront...        M5V  43.642778
# 14      [931 College St., Toronto ON M6H 1A1, Canada]        M6H  43.653626
# 15           [483 Bay St, Toronto ON M5G 2C9, Canada]        M5G  43.653743
# 16  [266 King Street West (Duncan), Toronto ON, Ca...        NaN  43.647017
# 17     [64 Ossington Ave, Toronto ON M6J 1X6, Canada]        M6J  43.645717
# 18              [Liberty Village, Toronto ON, Canada]        NaN  43.637036
# 19  [36 Toronto St,210 (at Victoria St.), Toronto ...        M5C  43.650806
# 20  [7 Isabella Street (Yonge Street), Toronto ON ...        M4Y  43.667484
# 21  [8 Park Rd (at Bloor St. E.), Toronto ON M4W 3...        M4W  43.671398
# 22  [370 Queens Quay W, Unit 114 (Spadina Ave), To...        M5V  43.638195
# 23  [55 Harbord St (University of Toronto), Toront...        M5S  43.662487
# 24  [85 Hanna Ave (at Snooker St.), Toronto ON M6K...        M6K  43.640175
# 25  [148 Ossington Avenue (Dundas), Toronto ON M6J...        M6J  43.647607
# 26  [44 Price St. (at Yonge St.), Toronto ON, Canada]        NaN  43.680667
# 27  [625 Queen St. W., 3rd Fl. (nr Bathurst St.), ...        M5V  43.647323
# 28  [79 Wellington Street West, Toronto ON M5K 1J5...        M5K  43.647360
# 29  [388 Carlaw Ave. (at Dundas (Suite 204)), Toro...        M4M  43.665880
#
#           lng          venue.categories  venue.categorie.name
# 0  -79.378797  4bf58dd8d48988d176941735                   Gym
# 1  -79.379989  4bf58dd8d48988d176941735                   Gym
# 2  -79.402660  4bf58dd8d48988d176941735                   Gym
# 3  -79.381921  4bf58dd8d48988d175941735  Gym / Fitness Center
# 4  -79.395918  4bf58dd8d48988d176941735                   Gym
# 5  -79.390940  4bf58dd8d48988d175941735  Gym / Fitness Center
# 6  -79.397917  4bf58dd8d48988d176941735                   Gym
# 7  -79.391143  4bf58dd8d48988d176941735                   Gym
# 8  -79.394963  4bf58dd8d48988d176941735                   Gym
# 9  -79.403185  4bf58dd8d48988d102941735           Yoga Studio
# 10 -79.357947  4bf58dd8d48988d175941735  Gym / Fitness Center
# 11 -79.384849  4bf58dd8d48988d176941735                   Gym
# 12 -79.392067  4bf58dd8d48988d176941735                   Gym
# 13 -79.402361  4bf58dd8d48988d175941735  Gym / Fitness Center
# 14 -79.426092  4bf58dd8d48988d176941735                   Gym
# 15 -79.382705  4bf58dd8d48988d176941735                   Gym
# 16 -79.388143  4bf58dd8d48988d176941735                   Gym
# 17 -79.419437  4bf58dd8d48988d175941735  Gym / Fitness Center
# 18 -79.424802  4bf58dd8d48988d176941735                   Gym
# 19 -79.376693  4bf58dd8d48988d176941735                   Gym
# 20 -79.385510  4bf58dd8d48988d176941735                   Gym
# 21 -79.384408  4bf58dd8d48988d176941735                   Gym
# 22 -79.390696  4bf58dd8d48988d176941735                   Gym
# 23 -79.400657  4bf58dd8d48988d1b2941735           College Gym
# 24 -79.419791  4bf58dd8d48988d176941735                   Gym
# 25 -79.420133  4bf58dd8d48988d102941735           Yoga Studio
# 26 -79.388559  4f4528bc4b90abdf24c9de85    Athletics & Sports
# 27 -79.402964  4bf58dd8d48988d175941735  Gym / Fitness Center
# 28 -79.381177  4bf58dd8d48988d176941735                   Gym
# 29 -79.342794  503289d391d4c4b30a586d6a          Climbing Gym

# %% [markdown]
# ### 2.4.3. Getting Gyms Count Per Venue

# %%
Gym_per_Post.postalCode.value_counts(dropna=False).to_frame()
# Out:
#      postalCode
# M5V           9
# M5C           2
# M6J           2
# M4Y           2
# M6K           2
# M6H           1
# M5R           1
# M5L           1
# M4W           1
# M5S           1
# M5A           1
# M4T           1
# M5K           1
# M5J           1
# M5G           1
# M5H           1
# M5X           1
# M4M           1

# %% [markdown]
# ### 2.4.4. Filling Nan Values

# %%
def Calculate_Distant(lat2,lon2):
    # approximate radius of earth in km
    R = 6373.0
    _MinDis = 10000000000000000000000000
    _MinPC = ""
    for lat1,lon1,_pc in zip(df['Latitude'],df['Longitude'],df['Postcode']):
        dlon = lon2 - lon1
        dlat = lat2 - lat1
        a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
        c = 2 * atan2(sqrt(a), sqrt(1 - a))
        distance = R * c
        if(_MinDis >= distance):
            _MinDis = distance
            _MinPC = _pc
    return _MinPC

# %%
_nan = Gym_per_Post.loc[Gym_per_Post.postalCode.isnull(), ['name','formattedAddress','lat','lng']]
for lat,lng,index in zip(_nan.lat,_nan.lng,_nan.index):
    val = Calculate_Distant(lat,lng)
    Gym_per_Post.postalCode[index] = val
    print(val)
# Out:
#                                name  \
# 7                         Superclub
# 16                        Cardio-Go
# 18  Reebok Crossfit Liberty Village
# 26         Toronto Lawn Tennis Club
#
#                                      formattedAddress        lat        lng
# 7   [35 Mariner Terrace (Spadina Ave and Bremner B...  43.639761 -79.391143
# 16  [266 King Street West (Duncan), Toronto ON, Ca...  43.647017 -79.388143
# 18              [Liberty Village, Toronto ON, Canada]  43.637036 -79.424802
# 26  [44 Price St. (at Yonge St.), Toronto ON, Canada]  43.680667 -79.388559

# %%
Gym_per_Post.head(100)
# Out:
#                                                name  neighborhood  \
# 0                                  GoodLife Fitness           NaN
# 1                                Equinox Bay Street           NaN
# 2                                  GoodLife Fitness           NaN
# 3                             Adelaide Club Toronto           NaN
# 4                           Totum Life Science King           NaN
# 5                    barre3 Toronto - King St. West           NaN
# 6                                Fuel Training Club           NaN
# 7                                         Superclub           NaN
# 8                                 Equinox Yorkville           NaN
# 9                              Moksha Yoga Downtown           NaN
# 10  Toronto Cooper Koo Family Cherry St YMCA Centre           NaN
# 11                                             YMCA           NaN
# 12           GoodLife Fitness Toronto Richmond John           NaN
# 13                                             Cykl           NaN
# 14                                    West End YMCA           NaN
# 15                                 GoodLife Fitness           NaN
# 16                                        Cardio-Go           NaN
# 17                Academy Of Lions CrossFit Toronto           NaN
# 18                  Reebok Crossfit Liberty Village           NaN
# 19                                 GoodLife Fitness           NaN
# 20                                     Hone Fitness           NaN
# 21              GoodLife Fitness Toronto Bloor Park           NaN
# 22                                     Crossfit 416           NaN
# 23                                  Athletic Centre           NaN
# 24            GoodLife Fitness Toronto King Liberty           NaN
# 25                                        YogaSpace           NaN
# 26                         Toronto Lawn Tennis Club           NaN
# 27                                       Barreworks           NaN
# 28                            Toronto Athletic Club           NaN
# 29                                       Rock Oasis           NaN
#
#                                            categories  \
# 0   [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 1   [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 2   [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 3   [{'id': '4bf58dd8d48988d175941735', 'name': 'G...
# 4   [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 5   [{'id': '4bf58dd8d48988d175941735', 'name': 'G...
# 6   [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 7   [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 8   [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 9   [{'id': '4bf58dd8d48988d102941735', 'name': 'Y...
# 10  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...
# 11  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 12  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 13  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...
# 14  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 15  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 16  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 17  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...
# 18  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 19  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 20  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 21  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 22  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 23  [{'id': '4bf58dd8d48988d1b2941735', 'name': 'C...
# 24  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 25  [{'id': '4bf58dd8d48988d102941735', 'name': 'Y...
# 26  [{'id': '4f4528bc4b90abdf24c9de85', 'name': 'A...
# 27  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...
# 28  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 29  [{'id': '503289d391d4c4b30a586d6a', 'name': 'C...
#
#                         address                         crossStreet  \
# 0                  137 Yonge St                      at Richmond St
# 1                    199 Bay St  at Commerce Court West, PATH Level
# 2             555 Richmond St W               Bathurst and Richmond
# 3        1 First Canadian Place                                 NaN
# 4                445 King St. W                     at Spadina Ave.
# 5          325 King Street West                                 NaN
# 6         45 camden st unit 100                             spadina
# 7            35 Mariner Terrace        Spadina Ave and Bremner Blvd
# 8                55 Avenue Road                                 NaN
# 9           577 Wellington St W                      at Bathurst St
# 10            461 Cherry Street                                 NaN
# 11              20 Grosvenor St  btwn St. Vincent Ln & St. Lukes Ln
# 12            267 Richmond St W                                 NaN
# 13              68 Bathurst St.                 At Wellington St. W
# 14              931 College St.                                 NaN
# 15                   483 Bay St                                 NaN
# 16         266 King Street West                              Duncan
# 17             64 Ossington Ave                                 NaN
# 18              Liberty Village                                 NaN
# 19            36 Toronto St,210                     at Victoria St.
# 20            7 Isabella Street                        Yonge Street
# 21                    8 Park Rd                     at Bloor St. E.
# 22  370 Queens Quay W, Unit 114                         Spadina Ave
# 23                55 Harbord St               University of Toronto
# 24                 85 Hanna Ave                      at Snooker St.
# 25         148 Ossington Avenue                              Dundas
# 26                 44 Price St.                        at Yonge St.
# 27    625 Queen St. W., 3rd Fl.                     nr Bathurst St.
# 28    79 Wellington Street West                                 NaN
# 29              388 Carlaw Ave.               at Dundas (Suite 204)
#
#                                      formattedAddress postalCode        lat  \
# 0   [137 Yonge St (at Richmond St), Toronto ON M5C...        M5C  43.651136
# 1   [199 Bay St (at Commerce Court West, PATH Leve...        M5L  43.648100
# 2   [555 Richmond St W (Bathurst and Richmond), To...        M5V  43.646556
# 3   [1 First Canadian Place, Toronto ON M5X 1C8, C...        M5X  43.649279
# 4   [445 King St. W (at Spadina Ave.), Toronto ON ...        M5V  43.645151
# 5   [325 King Street West, Toronto ON M5V 1M3, Can...        M5V  43.646318
# 6   [45 camden st unit 100 (spadina), Toronto ON m...        M5V  43.646823
# 7   [35 Mariner Terrace (Spadina Ave and Bremner B...        M5J  43.639761
# 8        [55 Avenue Road, Toronto ON M5R 1B9, Canada]        M5R  43.671220
# 9   [577 Wellington St W (at Bathurst St), Toronto...        M5V  43.642353
# 10    [461 Cherry Street, Toronto ON M5A 1H1, Canada]        M5A  43.653191
# 11  [20 Grosvenor St (btwn St. Vincent Ln & St. Lu...        M4Y  43.662753
# 12    [267 Richmond St W, Toronto ON M5V 3M6, Canada]        M5V  43.648717
# 13  [68 Bathurst St. (At Wellington St. W), Toront...        M5V  43.642778
# 14      [931 College St., Toronto ON M6H 1A1, Canada]        M6H  43.653626
# 15           [483 Bay St, Toronto ON M5G 2C9, Canada]        M5G  43.653743
# 16  [266 King Street West (Duncan), Toronto ON, Ca...        M5H  43.647017
# 17     [64 Ossington Ave, Toronto ON M6J 1X6, Canada]        M6J  43.645717
# 18              [Liberty Village, Toronto ON, Canada]        M6K  43.637036
# 19  [36 Toronto St,210 (at Victoria St.), Toronto ...        M5C  43.650806
# 20  [7 Isabella Street (Yonge Street), Toronto ON ...        M4Y  43.667484
# 21  [8 Park Rd (at Bloor St. E.), Toronto ON M4W 3...        M4W  43.671398
# 22  [370 Queens Quay W, Unit 114 (Spadina Ave), To...        M5V  43.638195
# 23  [55 Harbord St (University of Toronto), Toront...        M5S  43.662487
# 24  [85 Hanna Ave (at Snooker St.), Toronto ON M6K...        M6K  43.640175
# 25  [148 Ossington Avenue (Dundas), Toronto ON M6J...        M6J  43.647607
# 26  [44 Price St. (at Yonge St.), Toronto ON, Canada]        M4T  43.680667
# 27  [625 Queen St. W., 3rd Fl. (nr Bathurst St.), ...        M5V  43.647323
# 28  [79 Wellington Street West, Toronto ON M5K 1J5...        M5K  43.647360
# 29  [388 Carlaw Ave. (at Dundas (Suite 204)), Toro...        M4M  43.665880
#
#           lng          venue.categories  venue.categorie.name
# 0  -79.378797  4bf58dd8d48988d176941735                   Gym
# 1  -79.379989  4bf58dd8d48988d176941735                   Gym
# 2  -79.402660  4bf58dd8d48988d176941735                   Gym
# 3  -79.381921  4bf58dd8d48988d175941735  Gym / Fitness Center
# 4  -79.395918  4bf58dd8d48988d176941735                   Gym
# 5  -79.390940  4bf58dd8d48988d175941735  Gym / Fitness Center
# 6  -79.397917  4bf58dd8d48988d176941735                   Gym
# 7  -79.391143  4bf58dd8d48988d176941735                   Gym
# 8  -79.394963  4bf58dd8d48988d176941735                   Gym
# 9  -79.403185  4bf58dd8d48988d102941735           Yoga Studio
# 10 -79.357947  4bf58dd8d48988d175941735  Gym / Fitness Center
# 11 -79.384849  4bf58dd8d48988d176941735                   Gym
# 12 -79.392067  4bf58dd8d48988d176941735                   Gym
# 13 -79.402361  4bf58dd8d48988d175941735  Gym / Fitness Center
# 14 -79.426092  4bf58dd8d48988d176941735                   Gym
# 15 -79.382705  4bf58dd8d48988d176941735                   Gym
# 16 -79.388143  4bf58dd8d48988d176941735                   Gym
# 17 -79.419437  4bf58dd8d48988d175941735  Gym / Fitness Center
# 18 -79.424802  4bf58dd8d48988d176941735                   Gym
# 19 -79.376693  4bf58dd8d48988d176941735                   Gym
# 20 -79.385510  4bf58dd8d48988d176941735                   Gym
# 21 -79.384408  4bf58dd8d48988d176941735                   Gym
# 22 -79.390696  4bf58dd8d48988d176941735                   Gym
# 23 -79.400657  4bf58dd8d48988d1b2941735           College Gym
# 24 -79.419791  4bf58dd8d48988d176941735                   Gym
# 25 -79.420133  4bf58dd8d48988d102941735           Yoga Studio
# 26 -79.388559  4f4528bc4b90abdf24c9de85    Athletics & Sports
# 27 -79.402964  4bf58dd8d48988d175941735  Gym / Fitness Center
# 28 -79.381177  4bf58dd8d48988d176941735                   Gym
# 29 -79.342794  503289d391d4c4b30a586d6a          Climbing Gym

# %% [markdown]
# ### 2.5. Preparing the Data For The Map

# %%
GC = Gym_per_Post.postalCode.value_counts(dropna=False)
GC = pd.DataFrame({'Postcode':GC.index, 'Count':GC.values})
Final = pd.merge(df,GC , on ='Postcode')
Final.head(100)
# Out:
#    Postcode                                      Neighbourhood  \
# 0       M4M                                    Studio District
# 1       M4T                        Moore Park, Summerhill East
# 2       M4W                                           Rosedale
# 3       M4Y                               Church and Wellesley
# 4       M5A                          Harbourfront, Regent Park
# 5       M5C                                     St. James Town
# 6       M5G                                 Central Bay Street
# 7       M5H                           Adelaide, King, Richmond
# 8       M5J  Harbourfront East, Toronto Islands, Union Station
# 9       M5K           Design Exchange, Toronto Dominion Centre
# 10      M5L                     Commerce Court, Victoria Hotel
# 11      M5R                The Annex, North Midtown, Yorkville
# 12      M5S                     Harbord, University of Toronto
# 13      M5V  CN Tower, Bathurst Quay, Island airport, Harbo...
# 14      M5X             First Canadian Place, Underground city
# 15      M6H                       Dovercourt Village, Dufferin
# 16      M6J                           Little Portugal, Trinity
# 17      M6K       Brockton, Exhibition Place, Parkdale Village
#
#              Borough   Latitude  Longitude      dlat      dlon  Count
# 0       East Toronto  43.659526 -79.340923  0.019764  0.050220      1
# 1    Central Toronto  43.689574 -79.383160  0.049813  0.007983      1
# 2   Downtown Toronto  43.679563 -79.377529  0.039801  0.013614      1
# 3   Downtown Toronto  43.665860 -79.383160  0.026099  0.007983      2
# 4   Downtown Toronto  43.654260 -79.360636  0.014499  0.030507      1
# 5   Downtown Toronto  43.651494 -79.375418  0.011733  0.015725      2
# 6   Downtown Toronto  43.657952 -79.387383  0.018191  0.003761      1
# 7   Downtown Toronto  43.650571 -79.384568  0.010810  0.006576      1
# 8   Downtown Toronto  43.640816 -79.381752  0.001054  0.009391      1
# 9   Downtown Toronto  43.647177 -79.381576  0.007415  0.009567      1
# 10  Downtown Toronto  43.648198 -79.379817  0.008437  0.011326      1
# 11   Central Toronto  43.672710 -79.405678  0.032948  0.014535      1
# 12  Downtown Toronto  43.662696 -79.400049  0.022934  0.008906      1
# 13  Downtown Toronto  43.628947 -79.394420  0.010815  0.003277      9
# 14  Downtown Toronto  43.648429 -79.382280  0.008668  0.008863      1
# 15      West Toronto  43.669005 -79.442259  0.029244  0.051116      1
# 16      West Toronto  43.647927 -79.419750  0.008165  0.028606      2
# 17      West Toronto  43.636847 -79.428191  0.002914  0.037048      2

# %% [markdown]
# ### 2.6. Visualize the Map

# %%
Toranto_map = folium.Map(location=[43.652051, -79.382646], zoom_start=11) #Creating New Folium Map Object

folium.Choropleth(geo_data='Toranto.geojson',
                  key_on='feature.properties.DISTRICT',
                  fill_opacity=0.3,
                  line_opacity=0.8).add_to(Toranto_map)

lat = []                                                                  #A List for Calculating MidPoint
long = []                                                                 #A List For Calculating MidPoint



for _latitude, _longitude  in zip(Final['Latitude'], Final['Longitude']):
    lat.append(_latitude)                        #Appand Latitude
    long.append(_longitude)                      #Appand Logitude 

Range_Latitude = sum(lat)/len(lat)              #Calculating MidPoint Latitude
Range_Longitude = sum(long)/len(long)           #Calculating MidPoint Latitude

#Now to Calclate the Radius We'll Need to Identify the Fearthist Point From MidPoint
MidPoint_Radius = 100


#Low Level 
folium.CircleMarker(        
        [Range_Latitude, Range_Longitude],      #1- Latitude And Longitude
        radius=MidPoint_Radius * 3.5,                 #2- The Radius of the Circle
        popup="Low level",                       #3- The Lable That Will Pop Up
        color='Yellow',                         #4- The Color of the Circle
        fill=False,                             #5- Set Fill to True In Order to Fill the Circle
        fill_color='Yellow',                    #6- This Parameter Represents the Filling Color
        fill_opacity=0.1666,                       #7- The Level of Filling Opacity (Value Between 0 and 1)
        parse_html=False,                       #8-
        ).add_to(Toranto_map)                   #Lastly We Assign the Marker to Our Map

#Mid Level 
folium.CircleMarker(        
        [Range_Latitude, Range_Longitude],      #1- Latitude And Longitude
        radius=MidPoint_Radius * 2.25,                 #2- The Radius of the Circle
        popup="Mid level",                       #3- The Lable That Will Pop Up
        color='Orange',                         #4- The Color of the Circle
        fill=False,                             #5- Set Fill to True In Order to Fill the Circle
        fill_color='Orange',                    #6- This Parameter Represents the Filling Color
        fill_opacity=0.111,                       #7- The Level of Filling Opacity (Value Between 0 and 1)
        parse_html=False,                       #8-
        ).add_to(Toranto_map)                   #Lastly We Assign the Marker to Our Map

#High Level 
folium.CircleMarker(        
        [Range_Latitude, Range_Longitude],      #1- Latitude And Longitude
        radius=MidPoint_Radius,                 #2- The Radius of the Circle
        popup="High level",                       #3- The Lable That Will Pop Up
        color='IndianRed',                         #4- The Color of the Circle
        fill=False,                             #5- Set Fill to True In Order to Fill the Circle
        fill_color='IndianRed',                    #6- This Parameter Represents the Filling Color
        fill_opacity=0.0555555,                       #7- The Level of Filling Opacity (Value Between 0 and 1)
        parse_html=False,                       #8-
        ).add_to(Toranto_map)                   #Lastly We Assign the Marker to Our Map


# add markers to map
for _latitude, _longitude, _borough, _neighborhood , _pc in zip(Final['Latitude'], Final['Longitude'], Final['Borough'], Final['Neighbourhood'], Final['Postcode']):
    label = '{}, {}'.format(_neighborhood, _borough)
    label = folium.Popup(label, parse_html=True)

                                #In Order To Create a Circle Marker Like the One on Google Then We'll Use the Folium Object 'CircleMarker'
    folium.CircleMarker(        #And Add The Following Parameters: -
        [_latitude, _longitude],                #1- Latitude And Longitude
        radius=5,                               #2- The Radius of the Circle
        popup=label,                            #3- The Lable That Will Pop Up
        color='Red',                            #4- The Color of the Circle
        fill=True,                              #5- Set Fill to True In Order to Fill the Circle
        fill_color='Gray',                       #6- This Parameter Represents the Filling Color
        fill_opacity=1,                         #7- The Level of Filling Opacity (Value Between 0 and 1)
        parse_html=False,                       #8-
        ).add_to(Toranto_map)                   #Lastly We Assign the Marker to Our Map


Toranto_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
